# %% [markdown]
# Exercise 81:
#
# Create a DataFrame and calculate the cumulative product for each group.

# %%
import pandas as pd 
data = {'X':['foo','bar','foo','bar'],'Y':[1,2,3,4]}
df=pd.DataFrame(data)
df['producto_acumulado']=df.groupby('X')['Y'].cumprod()
print(df)
# Out:
#      X  Y  producto_acumulado
# 0  foo  1                   1
# 1  bar  2                   2
# 2  foo  3                   3
# 3  bar  4                   8

# %% [markdown]
# Exercise 82:
#
# Create a DataFrame with random values and calculate the expanding sum.

# %%
import pandas as pd 
import numpy as np 

data=np.random.rand(4,3)
df= pd.DataFrame(data, columns=['X','Y','Z'])
print(df)
df['expanding_suma']=df['X'].expanding().sum()
print(df)
# Out:
#           X         Y         Z
# 0  0.180402  0.677643  0.136112
# 1  0.773929  0.724092  0.562970
# 2  0.081599  0.889348  0.752195
# 3  0.242039  0.926851  0.139966
#           X         Y         Z  expanding_suma
# 0  0.180402  0.677643  0.136112        0.180402
# 1  0.773929  0.724092  0.562970        0.954331
# 2  0.081599  0.889348  0.752195        1.035929
# 3  0.242039  0.926851  0.139966        1.277968

# %% [markdown]
# Exercise 83:
#
# Create a DataFrame and calculate the expanding minimum for each group.

# %%
import pandas as pd 
data= {'X': ['foo', 'bar', 'foo', 'bar'], 'Y': [1, 2, 3, 4]}
df= pd.DataFrame(data)
df['Expanding_Min'] = df.groupby('X')['Y'].expanding().min().reset_index(level=0, drop=True)
print(df)
# Out:
#      X  Y  Expanding_Min
# 0  foo  1            1.0
# 1  bar  2            2.0
# 2  foo  3            1.0
# 3  bar  4            2.0

# %% [markdown]
# Exercise 84:
#
# Create a DataFrame with random values and calculate the expanding maximum for each group.

# %%
import pandas as pd 
import numpy as np

data=np.random.rand(4,3)
df=pd.DataFrame(data,columns=['X','Y','Z'])
df['Expanding_Max'] = df.groupby('X')['Y'].expanding().max().reset_index(level=0, drop=True)
print(df)
# Out:
#           X         Y         Z  Expanding_Max
# 0  0.684190  0.643622  0.256596       0.643622
# 1  0.244082  0.589590  0.522614       0.589590
# 2  0.971714  0.343487  0.428977       0.343487
# 3  0.856291  0.283722  0.874769       0.283722

# %% [markdown]
# Exercise 85:
#
# Create a DataFrame and calculate the expanding variance for each group.

# %%
import pandas as pd
data = {'X': ['foo', 'bar', 'foo', 'bar'], 'Y': [1, 2, 3, 4]}
df = pd.DataFrame(data)
df['Expanding_Var'] = df.groupby('X')['Y'].expanding().var().reset_index(level=0, drop=True)
print(df)
# Out:
#      X  Y  Expanding_Var
# 0  foo  1            NaN
# 1  bar  2            NaN
# 2  foo  3            2.0
# 3  bar  4            2.0

# %% [markdown]
# Exercise 86:
#
# Create a DataFrame with random values and calculate the expanding standard deviation.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df['Expanding_Std'] = df['X'].expanding().std()
print(df)
# Out:
#           X         Y         Z  Expanding_Std
# 0  0.585379  0.862009  0.085198            NaN
# 1  0.897835  0.334137  0.885221       0.220940
# 2  0.031051  0.561504  0.254308       0.438980
# 3  0.908086  0.273285  0.014053       0.411264

# %% [markdown]
# Exercise 87:
#
# Create a DataFrame and calculate the expanding covariance.

# %%
import pandas as pd
data = {'X': [1, 2, 3, 4], 'Y': [4, 3, 2, 1]}
df = pd.DataFrame(data)
df['Expanding_Cov'] = df['X'].expanding().cov(df['Y'])
print(df)
# Out:
#    X  Y  Expanding_Cov
# 0  1  4            NaN
# 1  2  3      -0.500000
# 2  3  2      -1.000000
# 3  4  1      -1.666667

# %% [markdown]
# Exercise 88:
#
# Create a DataFrame with random values and calculate the expanding correlation.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df['Expanding_Corr'] = df['X'].expanding().corr(df['Y'])
print(df)
# Out:
#           X         Y         Z  Expanding_Corr
# 0  0.586908  0.086114  0.187529             NaN
# 1  0.613062  0.866903  0.169236        1.000000
# 2  0.778155  0.347934  0.689503       -0.061417
# 3  0.261847  0.882126  0.710509       -0.542860

# %% [markdown]
# Exercise 89:
#
# Create a DataFrame and calculate the expanding median.

# %%
import pandas as pd
data = {'X': [1, 2, 3, 4, 5, 6]}
df = pd.DataFrame(data)
df['Expanding_Median'] = df['X'].expanding().median()
print(df)
# Out:
#    X  Expanding_Median
# 0  1               1.0
# 1  2               1.5
# 2  3               2.0
# 3  4               2.5
# 4  5               3.0
# 5  6               3.5

# %% [markdown]
# Exercise 90:
#
# Create a DataFrame with datetime index and calculate the expanding mean for each group.

# %%
import pandas as pd
date_range = pd.date_range(start='1/1/2020', periods=10, freq='D')
data = {'X': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar'], 'Y': range(10)}
df = pd.DataFrame(data, index=date_range)
df['Expanding_Mean'] = df.groupby('X')['Y'].expanding().mean().reset_index(level=0, drop=True)
print(df)
# Out:
#               X  Y  Expanding_Mean
# 2020-01-01  foo  0             0.0
# 2020-01-02  bar  1             1.0
# 2020-01-03  foo  2             1.0
# 2020-01-04  bar  3             2.0
# 2020-01-05  foo  4             2.0
# 2020-01-06  bar  5             3.0
# 2020-01-07  foo  6             3.0
# 2020-01-08  bar  7             4.0
# 2020-01-09  foo  8             4.0
# 2020-01-10  bar  9             5.0
