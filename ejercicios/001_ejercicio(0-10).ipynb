# %% [markdown]
# Create a DataFrame from a dictionary of lists

# %%
import pandas as pd 
data = {'x':[1,2,3,4], 'y':[5,6,7,8]}
df= pd.DataFrame(data)
print (df)
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# Select the first 3 rows of a DataFrame.

# %%
import pandas as pd 
data = {'x':[1,2,3,4],'y':[5,6,7,8]}
df=pd.DataFrame(data)
print ("data\n",df)
print("---"*8)
print("las 3 primeras filas:\n",df.head(3))
# Out:
# data
#     x  y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# ------------------------
# las 3 primeras filas:
#     x  y
# 0  1  5
# 1  2  6
# 2  3  7

# %% [markdown]
# Select the 'X' column from a DataFrame.

# %%
import pandas as pd 
data = {'x':[1,2,3,4],'y':[5,6,7,8]}
df=pd.DataFrame(data)
print("seleccionamos la columna 'X':\n ",df['x'])
# Out:
# seleccionamos la columna 'X':
#   0    1
# 1    2
# 2    3
# 3    4
# Name: x, dtype: int64

# %% [markdown]
# Filter rows based on a column condition.

# %%
import pandas as pd 
data = {'x':[1,2,3,4],'y':[5,6,7,8]}
df=pd.DataFrame(data)
filtro_df=df[df['x']>2]
print(filtro_df)
# Out:
#    x  y
# 2  3  7
# 3  4  8

# %% [markdown]
# Add a new column to an existing DataFrame.

# %%
import pandas as pd 
data ={'x':[1,2,3,4],'y':[5,6,7,8]}
df = pd.DataFrame(data)
df['z']=df['x']+df['y']

print(df)
# Out:
#    x  y   z
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %% [markdown]
# Remove a column from a DataFrame.

# %%
import pandas as pd 
data={'x':[1,2,3,4],'y':[5,6,7,8],'z':[6,8,10,12]}
df=pd.DataFrame(data)
df.drop(columns=['z'],inplace=True)
print (df)
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# Sort a DataFrame by a column.

# %%
import pandas as pd 
data ={'X': [4, 3, 2, 1], 'Y': [8, 7, 6, 5]}
df =pd.DataFrame(data)
df.sort_values(by='X',inplace=True)
print(df)
# Out:
#    X  Y
# 3  1  5
# 2  2  6
# 1  3  7
# 0  4  8

# %% [markdown]
# Group a DataFrame by a column and calculate the mean of each group.

# %%
import pandas as pd 
data={'x':[1, 2, 1, 2],'y':[5, 6, 7, 8]}
df=pd.DataFrame(data)

agrupar_df=df.groupby('x').mean()
print(df,"\n")
print("----"*8)
print(agrupar_df)
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  1  7
# 3  2  8
#
# --------------------------------
#      y
# x
# 1  6.0
# 2  7.0

# %% [markdown]
# Replace missing values in a DataFrame.

# %%
import pandas as pd 
data = {'X': [1, 2, None, 4], 'Y': [5, None, 7, 8]}
df=pd.DataFrame(data)
df.fillna(0,inplace=True)
print(df)
# Out:
#      X    Y
# 0  1.0  5.0
# 1  2.0  0.0
# 2  0.0  7.0
# 3  4.0  8.0

# %% [markdown]
# Convert a column to datetime.

# %%
import pandas as pd 
data = {'X': ['2020-01-01', '2020-01-02', '2020-01-03']}
df=pd.DataFrame(data)
df['x']=pd.to_datetime(df['X'])
print(df)
# Out:
#             X          x
# 0  2020-01-01 2020-01-01
# 1  2020-01-02 2020-01-02
# 2  2020-01-03 2020-01-03
