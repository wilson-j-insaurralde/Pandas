# %% [markdown]
# Exercise 71:
#
# Create a DataFrame with random values and calculate the quantiles.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
print(df.quantile([0.25, 0.5, 0.75]))
# Out:
#              X         Y         Z
# 0.25  0.403485  0.378723  0.007523
# 0.50  0.557996  0.538074  0.016516
# 0.75  0.681166  0.684133  0.123915

# %% [markdown]
# Exercise 72:
#
# Create a DataFrame and calculate the interquartile range (IQR).
# {IQR} = Q_3 - Q_1

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# X    0.292221
# Y    0.204512
# Z    0.230871
# dtype: float64

# %% [markdown]
# Exercise 73:
#
# Create a DataFrame with datetime index and calculate the rolling mean.

# %%
import pandas as pd
date_range = pd.date_range(start='1/1/2020', periods=10, freq='D')
data = {'X': range(10)}
df = pd.DataFrame(data, index=date_range)
df['Rolling_Mean'] = df['X'].rolling(window=3).mean()
print(df)
# Out:
#             X  Rolling_Mean
# 2020-01-01  0           NaN
# 2020-01-02  1           NaN
# 2020-01-03  2           1.0
# 2020-01-04  3           2.0
# 2020-01-05  4           3.0
# 2020-01-06  5           4.0
# 2020-01-07  6           5.0
# 2020-01-08  7           6.0
# 2020-01-09  8           7.0
# 2020-01-10  9           8.0

# %% [markdown]
# Exercise 74:
#
# Create a DataFrame and calculate the cumulative maximum.

# %%
import pandas as pd
data = {'X': [1, 2, 3, 2, 1]}
df = pd.DataFrame(data)
df['Cumulative_Max'] = df['X'].cummax()
print(df)
# Out:
#    X  Cumulative_Max
# 0  1               1
# 1  2               2
# 2  3               3
# 3  2               3
# 4  1               3

# %% [markdown]
# Exercise 75:
#
# Create a DataFrame and calculate the cumulative minimum.

# %%
import pandas as pd
data = {'X': [1, 2, 3, 2, 1]}
df = pd.DataFrame(data)
df['Cumulative_Min'] = df['X'].cummin()
print(df)
# Out:
#    X  Cumulative_Min
# 0  1               1
# 1  2               1
# 2  3               1
# 3  2               1
# 4  1               1

# %% [markdown]
# Exercise 76:
#
# Create a DataFrame with random values and calculate the cumulative variance.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(10, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df["Cumulative_Var_X"] = df["X"].expanding().var()
df["Cumulative_Var_Y"] = df["Y"].expanding().var()
df["Cumulative_Var_Z"] = df["Z"].expanding().var()
print(df)
# Out:
#           X         Y         Z  Cumulative_Var_X  Cumulative_Var_Y  \
# 0  0.890539  0.482043  0.931445               NaN               NaN
# 1  0.446666  0.366442  0.149875          0.098512          0.006682
# 2  0.035155  0.997652  0.761732          0.183008          0.112940
# 3  0.408553  0.265765  0.857795          0.122603          0.105851
# 4  0.500641  0.586398  0.356660          0.092567          0.080071
# 5  0.848115  0.420294  0.528890          0.099638          0.066431
# 6  0.019826  0.600295  0.768799          0.119002          0.056286
# 7  0.707455  0.162457  0.621902          0.110292          0.065248
# 8  0.112549  0.622554  0.493243          0.111681          0.059189
# 9  0.835408  0.497830  0.636025          0.114823          0.052613
#
#    Cumulative_Var_Z
# 0               NaN
# 1          0.305426
# 2          0.169004
# 3          0.127486
# 4          0.115909
# 5          0.093865
# 6          0.082401
# 7          0.070630
# 8          0.063647
# 9          0.056655

# %% [markdown]
# Exercise 77:
#
# Create a DataFrame and apply a custom function to each element.

# %%
import pandas as pd
data = {'X': [1, 2, 3], 'Y': [4, 5, 6]}
df = pd.DataFrame(data)
def custom_function(x):
    return x * 2
df = df.apply(lambda col: col.map(custom_function))
print(df)
# Out:
#    X   Y
# 0  2   8
# 1  4  10
# 2  6  12

# %% [markdown]
# Exercise 78:
#
# Create a DataFrame with random values and calculate the z-score for each element.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df = df.apply(lambda x: (x - x.mean()) / x.std(), axis=0)
print(df)
# Out:
#           X         Y         Z
# 0 -0.237539 -1.215332  1.114181
# 1 -0.804633 -0.115283  0.508056
# 2 -0.415151  0.106555 -1.114973
# 3  1.457323  1.224061 -0.507264

# %% [markdown]
# Exercise 79:
#
# Create a DataFrame and calculate the cumulative sum for each group.

# %%
import pandas as pd
data = {'X': ['foo', 'bar', 'foo', 'bar'], 'Y': [1, 2, 3, 4]}
df = pd.DataFrame(data)
df['Cumulative_Sum'] = df.groupby('X')['Y'].cumsum()
print(df)
# Out:
#      X  Y  Cumulative_Sum
# 0  foo  1               1
# 1  bar  2               2
# 2  foo  3               4
# 3  bar  4               6

# %% [markdown]
# Exercise 80:
#
# Create a DataFrame with random values and calculate the rank for each element.

# %%
import pandas as pd
import numpy as np
data = np.random.rand(4, 3)
df = pd.DataFrame(data, columns=['X', 'Y', 'Z'])
df = df.rank()
print(df)
# Out:
#      X    Y    Z
# 0  4.0  4.0  3.0
# 1  1.0  2.0  4.0
# 2  2.0  1.0  1.0
# 3  3.0  3.0  2.0
